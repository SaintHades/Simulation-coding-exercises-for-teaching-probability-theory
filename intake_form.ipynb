# %% [markdown]
# ## Participants 底下放这个
# We recruited participants from Data Science, Math, and Economics classes at UCSD.  Data collection took place during the first half of winter quarter. Selection of these courses aimed to target students with comparable quantitative backgrounds, ensuring a similar baseline level of mathematics and coding skills for completing the tasks in our study. We recruited 50 participants from data science–related courses at UC San Diego during the first half of the Winter quarter. Recruitment primarily occurred through courses such as DSC 10, DSC 20, DSC 140B, and DSC 180, with smaller numbers of participants from several other DSC courses. Outreach was conducted through in-class announcements and email invitations distributed by course instructors. Students who chose to participate first completed an intake questionnaire administered through Google Forms. The form collected background information including class standing, data science and mathematics affiliations, number of statistics courses taken, and self-reported familiarity with statistics, Python programming, and Chebyshev’s inequality. Among the participants, 29 identified as Data Science majors, 11 as Data Science minors, and 10 reported no formal Data Science affiliation. On a five-point scale, participants reported moderate Python proficiency (mean = 3.34) and relatively limited familiarity with Chebyshev’s inequality (mean = 2.50).

# %%
import pandas as pd

df = pd.read_csv("data/cleaned/intake_form.csv")

# %%
# Load the dataset and create several bar plots for key variables
import matplotlib.pyplot as plt

import pandas as pd

df = pd.read_csv("data/cleaned/intake_form.csv")

# 2. Bar plot for Data Science affiliation
aff_counts = df['dsc_affiliation'].value_counts()

plt.figure()
aff_counts.plot(kind='bar')
plt.xlabel("Data Science Affiliation")
plt.ylabel("Number of Participants")
plt.title("Participant Data Science Affiliation")
plt.tight_layout()
plt.savefig("data/intake_analyze/data_science_affiliation.png", dpi=300)
plt.show()


# 3. Bar plot for recruitment source (courses)
course_counts = df['recruitment_source'].value_counts()

plt.figure()
course_counts.plot(kind='bar')
plt.xlabel("Recruitment Course")
plt.ylabel("Number of Participants")
plt.title("Participant Recruitment by Course")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("data/intake_analyze/recruitment_course_distribution.png", dpi=300)
plt.show()
plt.show()

# %% [markdown]
# ## 用来表达我们想用两张图解释什么
# Students majoring in Data Science are more likely to have completed multiple statistics courses, and participants recruited from higher-level courses are also more likely to have stronger prior exposure to probability and statistical concepts. These characteristics may therefore act as confounding variables when examining the relationship between the teaching method used in the experiment and the final scores received by participants. Students with stronger prior training may achieve higher scores regardless of the instructional method they are assigned to. Consequently, differences in performance between teaching methods could partially reflect pre-existing background knowledge rather than the effect of the teaching intervention itself.
